# %% [markdown]
# 1. Write a Python program to print &quot;Hello Python&quot;?

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# 2. Write a Python program to do arithmetical operations addition and division.?

# %%
a = int(input("Enter the first Number: "))
b = int(input("Enter the second Number: "))

print("Summation:", a+b)
print("Division:", a/b)
print("Multiplication:", a*b)
print("Substration:", a-b)
# Out:
# Enter the first Number: 45
# Enter the second Number: 3
# Summation: 48
# Division: 15.0
# Multiplication: 135
# Substration: 42

# %% [markdown]
# 3. Write a Python program to find the area of a triangle?

# %%
base = int(input("Enter the Base of Triangle: "))
height = int(input("Enter the Height of Triangle: "))

print("Area of Triangle:", 0.5*base*height)
# Out:
# Enter the Base of Triangle: 50
# Enter the Height of Triangle: 34
# Area of Triangle: 850.0

# %% [markdown]
# 4. Write a Python program to swap two variables?

# %%
x = input("Enter the value of x: ")
y = input("Enter the value of y: ")

temp = x
x = y
y = temp

print("After Swapping, Value of x: {}".format(x))
print("After Swapping, Value of y: {}".format(y))
# Out:
# Enter the value of x: test
# Enter the value of y: 45.3
# After Swapping, Value of x: 45.3
# After Swapping, Value of y: test

# %% [markdown]
# 5. Write a Python program to generate a random number?

# %%
import random

print(random.randint(0, 50))
# Out:
# 24
